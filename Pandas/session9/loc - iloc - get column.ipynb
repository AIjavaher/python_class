# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('weather.csv')
df
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %% [markdown]
# # Get column/row

# %%
df.columns
# Out:
# Index(['Data.Precipitation', 'Date.Full', 'Date.Month', 'Date.Week of',
#        'Date.Year', 'Station.City', 'Station.Code', 'Station.Location',
#        'Station.State', 'Data.Temperature.Avg Temp',
#        'Data.Temperature.Max Temp', 'Data.Temperature.Min Temp',
#        'Data.Wind.Direction', 'Data.Wind.Speed'],
#       dtype='object')

# %%
df[['Date.Year','Date.Full']]
# Out:
#        Date.Year   Date.Full
# 0           2016  2016-01-03
# 1           2016  2016-01-03
# 2           2016  2016-01-03
# 3           2016  2016-01-03
# 4           2016  2016-01-03
# ...          ...         ...
# 16738       2017  2017-01-01
# 16739       2017  2017-01-01
# 16740       2017  2017-01-01
# 16741       2017  2017-01-01
# 16742       2017  2017-01-01
#
# [16743 rows x 2 columns]

# %%
df[['Date.Year','Date.Full']][0:10].values
# Out:
# array([[2016, '2016-01-03'],
#        [2016, '2016-01-03'],
#        [2016, '2016-01-03'],
#        [2016, '2016-01-03'],
#        [2016, '2016-01-03'],
#        [2016, '2016-01-03'],
#        [2016, '2016-01-03'],
#        [2016, '2016-01-03'],
#        [2016, '2016-01-03'],
#        [2016, '2016-01-03']], dtype=object)

# %%
df[['Date.Year','Date.Full']][0:10].index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
list(df[['Date.Year','Date.Full']][0:10].values)[2:]
# Out:
# [array([2016, '2016-01-03'], dtype=object),
#  array([2016, '2016-01-03'], dtype=object),
#  array([2016, '2016-01-03'], dtype=object),
#  array([2016, '2016-01-03'], dtype=object),
#  array([2016, '2016-01-03'], dtype=object),
#  array([2016, '2016-01-03'], dtype=object),
#  array([2016, '2016-01-03'], dtype=object),
#  array([2016, '2016-01-03'], dtype=object)]

# %% [markdown]
# # loc

# %%
df.loc[20:30][['Date.Full','Date.Year']]
# Out:
#      Date.Full  Date.Year
# 20  2016-01-03       2016
# 21  2016-01-03       2016
# 22  2016-01-03       2016
# 23  2016-01-03       2016
# 24  2016-01-03       2016
# 25  2016-01-03       2016
# 26  2016-01-03       2016
# 27  2016-01-03       2016
# 28  2016-01-03       2016
# 29  2016-01-03       2016
# 30  2016-01-03       2016

# %%
df.loc[20:30][['Date.Full','Date.Year']].values
# Out:
# array([['2016-01-03', 2016],
#        ['2016-01-03', 2016],
#        ['2016-01-03', 2016],
#        ['2016-01-03', 2016],
#        ['2016-01-03', 2016],
#        ['2016-01-03', 2016],
#        ['2016-01-03', 2016],
#        ['2016-01-03', 2016],
#        ['2016-01-03', 2016],
#        ['2016-01-03', 2016],
#        ['2016-01-03', 2016]], dtype=object)

# %%
df.loc[20:30][['Date.Full','Date.Year']].index
# Out:
# RangeIndex(start=20, stop=31, step=1)

# %%
list(df.loc[20:30][['Date.Full','Date.Year']].values)[-1]
# Out:
# array(['2016-01-03', 2016], dtype=object)

# %% [markdown]
# # Condition

# %%
df['Date.Year']==2016
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 16738    False
# 16739    False
# 16740    False
# 16741    False
# 16742    False
# Name: Date.Year, Length: 16743, dtype: bool

# %%
df.loc[(df['Date.Year']==2016)&(df['Date.Month']>6)]
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 8209                 0.00  2016-07-03           7             3       2016
# 8210                 0.06  2016-07-03           7             3       2016
# 8211                 0.00  2016-07-03           7             3       2016
# 8212                 0.00  2016-07-03           7             3       2016
# 8213                 0.35  2016-07-03           7             3       2016
# ...                   ...         ...         ...           ...        ...
# 16421                0.39  2016-12-25          12            25       2016
# 16422                0.04  2016-12-25          12            25       2016
# 16423                0.33  2016-12-25          12            25       2016
# 16424                0.36  2016-12-25          12            25       2016
# 16425                0.30  2016-12-25          12            25       2016
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
df.loc[(df['Date.Year']==2016)&(df['Date.Month']>6)][['Station.City','Station.Code']]
# Out:
#       Station.City Station.Code
# 8209    Birmingham          BHM
# 8210    Huntsville          HSV
# 8211        Mobile          MOB
# 8212    Montgomery          MGM
# 8213     Anchorage          ANC
# ...            ...          ...
# 16421       Casper          CPR
# 16422     Cheyenne          CYS
# 16423       Lander          LND
# 16424      Rawlins          RWL
# 16425     Sheridan          SHR
#
# [8217 rows x 2 columns]

# %%
df.loc[(df['Date.Year']==2016)&(df['Date.Month']>6)][['Station.City','Station.Code']].values
# Out:
# array([['Birmingham', 'BHM'],
#        ['Huntsville', 'HSV'],
#        ['Mobile', 'MOB'],
#        ...,
#        ['Lander', 'LND'],
#        ['Rawlins', 'RWL'],
#        ['Sheridan', 'SHR']], dtype=object)

# %%
df.loc[(df['Date.Year']==2016)&(df['Date.Month']>6)][['Station.City','Station.Code']].index
# Out:
# Int64Index([ 8209,  8210,  8211,  8212,  8213,  8214,  8215,  8216,  8217,
#              8218,
#             ...
#             16416, 16417, 16418, 16419, 16420, 16421, 16422, 16423, 16424,
#             16425],
#            dtype='int64', length=8217)

# %%
list(df.loc[(df['Date.Year']==2016)&(df['Date.Month']>6)][['Station.City','Station.Code']].values)[5:]
# Out:
# [array(['Annette', 'ANN'], dtype=object),
#  array(['Bethel', 'BET'], dtype=object),
#  array(['Bettles', 'BTT'], dtype=object),
#  array(['Cold Bay', 'CDB'], dtype=object),
#  array(['Cordova', 'CDV'], dtype=object),
#  array(['Delta Junction/Ft Greely', 'BIG'], dtype=object),
#  array(['Fairbanks', 'FAI'], dtype=object),
#  array(['Gulkana', 'GKN'], dtype=object),
#  array(['Gustavus', 'GST'], dtype=object),
#  array(['Homer', 'HOM'], dtype=object),
#  array(['Iliamna', 'ILI'], dtype=object),
#  array(['Juneau', 'JNU'], dtype=object),
#  array(['Kenai', 'ENA'], dtype=object),
#  array(['Ketchikan', 'KTN'], dtype=object),
#  array(['King Salmon', 'AKN'], dtype=object),
#  array(['Kodiak', 'ADQ'], dtype=object),
#  array(['Kotzebue', 'OTZ'], dtype=object),
#  array(['Mc Grath', 'MCG'], dtype=object),
#  array(['Nome', 'OME'], dtype=object),
#  array(['Northway', 'ORT'], dtype=object),
#  array(['Palmer', 'PAQ'], dtype=object),
#  array(['Petersburg', 'PSG'], dtype=object),
# ...

# %% [markdown]
# # iloc

# %%
df.iloc[20:30,0:5]
# Out:
#     Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year
# 20                0.10  2016-01-03           1             3       2016
# 21                0.01  2016-01-03           1             3       2016
# 22                0.08  2016-01-03           1             3       2016
# 23                0.00  2016-01-03           1             3       2016
# 24                0.40  2016-01-03           1             3       2016
# 25                0.00  2016-01-03           1             3       2016
# 26                0.00  2016-01-03           1             3       2016
# 27                0.00  2016-01-03           1             3       2016
# 28                0.37  2016-01-03           1             3       2016
# 29                0.55  2016-01-03           1             3       2016

# %%
df.loc[20:30]
# Out:
#     Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 20                0.10  2016-01-03           1             3       2016
# 21                0.01  2016-01-03           1             3       2016
# 22                0.08  2016-01-03           1             3       2016
# 23                0.00  2016-01-03           1             3       2016
# 24                0.40  2016-01-03           1             3       2016
# 25                0.00  2016-01-03           1             3       2016
# 26                0.00  2016-01-03           1             3       2016
# 27                0.00  2016-01-03           1             3       2016
# 28                0.37  2016-01-03           1             3       2016
# 29                0.55  2016-01-03           1             3       2016
# 30                0.15  2016-01-03           1             3       2016
#
#       Station.City Station.Code    Station.Location Station.State  \
# ...

# %%
df.iloc[20:30,0:5].values
# Out:
# array([[0.1, '2016-01-03', 1, 3, 2016],
#        [0.01, '2016-01-03', 1, 3, 2016],
#        [0.08, '2016-01-03', 1, 3, 2016],
#        [0.0, '2016-01-03', 1, 3, 2016],
#        [0.4, '2016-01-03', 1, 3, 2016],
#        [0.0, '2016-01-03', 1, 3, 2016],
#        [0.0, '2016-01-03', 1, 3, 2016],
#        [0.0, '2016-01-03', 1, 3, 2016],
#        [0.37, '2016-01-03', 1, 3, 2016],
#        [0.55, '2016-01-03', 1, 3, 2016]], dtype=object)

# %%
df.iloc[20:30,0:5].index
# Out:
# RangeIndex(start=20, stop=30, step=1)

# %%
list(df.iloc[20:30,0:5].values)[1:]
# Out:
# [array([0.01, '2016-01-03', 1, 3, 2016], dtype=object),
#  array([0.08, '2016-01-03', 1, 3, 2016], dtype=object),
#  array([0.0, '2016-01-03', 1, 3, 2016], dtype=object),
#  array([0.4, '2016-01-03', 1, 3, 2016], dtype=object),
#  array([0.0, '2016-01-03', 1, 3, 2016], dtype=object),
#  array([0.0, '2016-01-03', 1, 3, 2016], dtype=object),
#  array([0.0, '2016-01-03', 1, 3, 2016], dtype=object),
#  array([0.37, '2016-01-03', 1, 3, 2016], dtype=object),
#  array([0.55, '2016-01-03', 1, 3, 2016], dtype=object)]

# %%
integer + loc
