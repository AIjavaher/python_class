# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # First

# %%
# array

# %%
data = np.array([[1,2,3],
                [4,5,6]])
df1 = pd.DataFrame(data =  data, columns = ['a', 'b', 'c'], index = ['ind1', 'ind2'])
df1
# Out:
#       a  b  c
# ind1  1  2  3
# ind2  4  5  6

# %% [markdown]
# # Second

# %%
# dic

# %%
data = {'name':['john', 'jack', 'rose'], 'age':[12,25,38]}
df2 = pd.DataFrame(data = data, index = np.arange(3))
df2
# Out:
#    name  age
# 0  john   12
# 1  jack   25
# 2  rose   38

# %% [markdown]
# # Third

# %%
# empty

# %%
df3 = pd.DataFrame(columns = ['a','b','c'], index = np.arange(100))
df3
# Out:
#       a    b    c
# 0   NaN  NaN  NaN
# 1   NaN  NaN  NaN
# 2   NaN  NaN  NaN
# 3   NaN  NaN  NaN
# 4   NaN  NaN  NaN
# ..  ...  ...  ...
# 95  NaN  NaN  NaN
# 96  NaN  NaN  NaN
# 97  NaN  NaN  NaN
# 98  NaN  NaN  NaN
# 99  NaN  NaN  NaN
#
# [100 rows x 3 columns]

# %% [markdown]
# # Forth

# %%
# read

# %%
df4 = pd.read_csv('weather.csv')
df4
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
df4 = pd.read_csv('weather.csv', header=1)
df4
# Out:
#         0.0  2016-01-03  1  3  2016  Birmingham  BHM  Birmingham, AL  Alabama  \
# 0      0.00  2016-01-03  1  3  2016  Huntsville  HSV  Huntsville, AL  Alabama
# 1      0.16  2016-01-03  1  3  2016      Mobile  MOB      Mobile, AL  Alabama
# 2      0.00  2016-01-03  1  3  2016  Montgomery  MGM  Montgomery, AL  Alabama
# 3      0.01  2016-01-03  1  3  2016   Anchorage  ANC   Anchorage, AK   Alaska
# 4      0.09  2016-01-03  1  3  2016     Annette  ANN     Annette, AK   Alaska
# ...     ...         ... .. ..   ...         ...  ...             ...      ...
# 16737  0.08  2017-01-01  1  1  2017      Casper  CPR      Casper, WY  Wyoming
# 16738  0.00  2017-01-01  1  1  2017    Cheyenne  CYS    Cheyenne, WY  Wyoming
# 16739  0.00  2017-01-01  1  1  2017      Lander  LND      Lander, WY  Wyoming
# 16740  0.06  2017-01-01  1  1  2017     Rawlins  RWL     Rawlins, WY  Wyoming
# 16741  0.10  2017-01-01  1  1  2017    Sheridan  SHR    Sheridan, WY  Wyoming
#
#        39  46  32  33   4.33
# ...

# %%
df4 = pd.read_csv('weather.csv', names = np.arange(14))
df4
# Out:
#                        0           1           2             3          4   \
# 0      Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year
# 1                     0.0  2016-01-03           1             3       2016
# 2                     0.0  2016-01-03           1             3       2016
# 3                    0.16  2016-01-03           1             3       2016
# 4                     0.0  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16739                0.08  2017-01-01           1             1       2017
# 16740                 0.0  2017-01-01           1             1       2017
# 16741                 0.0  2017-01-01           1             1       2017
# 16742                0.06  2017-01-01           1             1       2017
# 16743                 0.1  2017-01-01           1             1       2017
#
# ...

# %%
df4.head(200)
# Out:
#                      0           1           2             3          4   \
# 0    Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year
# 1                   0.0  2016-01-03           1             3       2016
# 2                   0.0  2016-01-03           1             3       2016
# 3                  0.16  2016-01-03           1             3       2016
# 4                   0.0  2016-01-03           1             3       2016
# ..                  ...         ...         ...           ...        ...
# 195                 0.0  2016-01-03           1             3       2016
# 196                 0.0  2016-01-03           1             3       2016
# 197                0.02  2016-01-03           1             3       2016
# 198                0.01  2016-01-03           1             3       2016
# 199                0.01  2016-01-03           1             3       2016
#
#                5             6                 7              8   \
# ...

# %%
df4.tail(30)
# Out:
#          0           1  2  3     4               5    6                   7   \
# 16714   0.0  2017-01-01  1  1  2017   Wichita Falls  SPS   Wichita Falls, TX
# 16715   0.0  2017-01-01  1  1  2017  Salt Lake City  SLC  Salt Lake City, UT
# 16716  0.26  2017-01-01  1  1  2017      Blacksburg  BCB      Blacksburg, VA
# 16717  0.42  2017-01-01  1  1  2017      Burlington  BTV      Burlington, VT
# 16718  0.23  2017-01-01  1  1  2017       Lynchburg  LYH       Lynchburg, VA
# 16719  0.19  2017-01-01  1  1  2017         Norfolk  ORF         Norfolk, VA
# 16720  0.22  2017-01-01  1  1  2017        Richmond  RIC        Richmond, VA
# 16721  0.26  2017-01-01  1  1  2017         Roanoke  ROA         Roanoke, VA
# 16722  0.09  2017-01-01  1  1  2017  Wallops Island  WAL  Wallops Island, VA
# 16723  0.24  2017-01-01  1  1  2017      Washington  DCA      Washington, VA
# 16724  0.21  2017-01-01  1  1  2017       Deer Park  DEW       Deer Park, WA
# ...

# %%
df4.sample(20)
# Out:
#          0           1   2   3     4                         5    6   \
# 9914   0.91  2016-08-07   8   7  2016                   Caribou  CAR
# 4741   0.02  2016-04-17   4  17  2016  Delta Junction/Ft Greely  BIG
# 189     0.0  2016-01-03   1   3  2016                      Reno  RNO
# 11028   0.0  2016-08-28   8  28  2016            Wallops Island  WAL
# 13011  0.21  2016-10-16  10  16  2016               Santa Maria  SMX
# 4449   0.01  2016-04-10   4  10  2016        Utqiagvik (Barrow)  BRW
# 6711   0.35  2016-05-29   5  29  2016                   Orlando  MCO
# 10298   1.6  2016-08-14   8  14  2016                    Albany  ALB
# 14559   0.0  2016-11-20  11  20  2016                    Shemya  SYA
# 6745   1.02  2016-05-29   5  29  2016                  Waterloo  ALO
# 8819   0.79  2016-07-10   7  10  2016                Washington  DCA
# 9471   0.54  2016-07-31   7  31  2016                Montgomery  MGM
# 15022  0.78  2016-11-27  11  27  2016                   Norfolk  OFK
# ...
